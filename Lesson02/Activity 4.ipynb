# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
df = pd.read_csv(url)

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, delim_whitespace=True)

# %%
df_g = df.groupby(['year', 'cylinders'], as_index=False)

# %%
df_g = df_g.mpg.mean()
df_g
# Out:
#     year  cylinders        mpg
# 0     70          4  25.285714
# 1     70          6  20.500000
# 2     70          8  14.111111
# 3     71          4  27.461538
# 4     71          6  18.000000
# 5     71          8  13.428571
# 6     72          3  19.000000
# 7     72          4  23.428571
# 8     72          8  13.615385
# 9     73          3  18.000000
# 10    73          4  22.727273
# 11    73          6  19.000000
# 12    73          8  13.200000
# 13    74          4  27.800000
# 14    74          6  17.857143
# 15    74          8  14.200000
# 16    75          4  25.250000
# 17    75          6  17.583333
# 18    75          8  15.666667
# 19    76          4  26.766667
# 20    76          6  20.000000
# 21    76          8  14.666667
# 22    77          3  21.500000
# 23    77          4  29.107143
# 24    77          6  19.500000
# 25    77          8  16.000000
# 26    78          4  29.576471
# 27    78          5  20.300000
# 28    78          6  19.066667
# 29    78          8  19.050000
# 30    79          4  31.525000
# 31    79          5  25.400000
# 32    79          6  22.950000
# 33    79          8  18.630000
# 34    80          3  23.700000
# 35    80          4  34.612000
# 36    80          5  36.400000
# 37    80          6  25.900000
# 38    81          4  32.814286
# 39    81          6  23.428571
# 40    81          8  26.600000
# 41    82          4  32.071429
# 42    82          6  28.333333

# %%
df_g = df_g.set_index(df_g.year)
df_g
# Out:
#       year  cylinders        mpg
# year
# 70      70          4  25.285714
# 70      70          6  20.500000
# 70      70          8  14.111111
# 71      71          4  27.461538
# 71      71          6  18.000000
# 71      71          8  13.428571
# 72      72          3  19.000000
# 72      72          4  23.428571
# 72      72          8  13.615385
# 73      73          3  18.000000
# 73      73          4  22.727273
# 73      73          6  19.000000
# 73      73          8  13.200000
# 74      74          4  27.800000
# 74      74          6  17.857143
# 74      74          8  14.200000
# 75      75          4  25.250000
# 75      75          6  17.583333
# 75      75          8  15.666667
# 76      76          4  26.766667
# 76      76          6  20.000000
# 76      76          8  14.666667
# 77      77          3  21.500000
# 77      77          4  29.107143
# 77      77          6  19.500000
# 77      77          8  16.000000
# 78      78          4  29.576471
# 78      78          5  20.300000
# 78      78          6  19.066667
# 78      78          8  19.050000
# 79      79          4  31.525000
# 79      79          5  25.400000
# 79      79          6  22.950000
# 79      79          8  18.630000
# 80      80          3  23.700000
# 80      80          4  34.612000
# 80      80          5  36.400000
# 80      80          6  25.900000
# 81      81          4  32.814286
# 81      81          6  23.428571
# 81      81          8  26.600000
# 82      82          4  32.071429
# 82      82          6  28.333333

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots()

# %%
df_g = df.groupby(['year', 'cylinders'], as_index=False).horsepower.mean()
df_g = df_g.set_index(df_g.year)
fig, axes = plt.subplots()
df_g.groupby('cylinders').horsepower.plot(axes=axes, figsize=(12,10))
_ = axes.set(
    title="Average car power per year",
    xlabel="Year",
    ylabel="Power (horsepower)"
)
axes.legend(title='cylinders', fancybox=True)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-44-b0f5607cb55c> in <module>()
# ----> 1 df_g = df.groupby(['year', 'cylinders'], as_index=False).horsepower.mean()
#       2 df_g = df_g.set_index(df_g.year)
#       3 fig, axes = plt.subplots()
#       4 df_g.groupby('cylinders').horsepower.plot(axes=axes, figsize=(12,10))
#       5 _ = axes.set(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     141
#     142         if len(new_blocks) == 0:
# --> 143             raise DataError('No numeric types to aggregate')
#     144
#     145         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %%
df = df.convert_objects(convert_numeric=True)
df_g = df.groupby(['year', 'cylinders'], as_index=False).horsepower.mean()
df_g = df_g.set_index(df_g.year)
fig, axes = plt.subplots()
df_g.groupby('cylinders').horsepower.plot(axes=axes, figsize=(12,10))
_ = axes.set(
    title="Average car power per year",
    xlabel="Year",
    ylabel="Power (horsepower)"    
)
axes.legend(title='Cylinders', fancybox=True)
fig.savefig('mpg_cylinder_year.png')
# Out:
# C:\Users\steffim\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
axes.legend(title='cylinders', fancybox=True)

# %%
fig.savefig('mpg_cylinder_year.png')
