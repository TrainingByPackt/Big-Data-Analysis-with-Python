# %% [markdown]
# ## Exercise 8: Working with Matplotlib Style Sheets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['seaborn-bright', 'seaborn-pastel', 'seaborn-dark', 'seaborn-deep', 'seaborn', 'seaborn-notebook', 'ggplot', 'bmh', 'seaborn-poster', 'seaborn-whitegrid', 'fivethirtyeight', 'dark_background', 'seaborn-talk', 'fast', 'tableau-colorblind10', '_classic_test', 'seaborn-muted', 'seaborn-paper', 'Solarize_Light2', 'classic', 'seaborn-darkgrid', 'seaborn-colorblind', 'seaborn-white', 'grayscale', 'seaborn-ticks', 'seaborn-dark-palette']

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


url = ('https://raw.githubusercontent.com/TrainingByPackt/Big-Data-Analysis-with-Python/master/Lesson02/Dataset/auto-mpg.data')
df = pd.read_csv(url)
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv(url, names= column_names, delim_whitespace=True)

df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])

plt.style.use(['classic'])
df.plot(kind='scatter', x='weight', y='horsepower')
