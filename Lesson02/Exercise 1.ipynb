# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x = np.linspace(-50, 50, 100)
y = np.power(x, 2)

# %%
plt.plot(x, y)

# %%
y_hat = np.power(x, 3)
plt.plot(x, y_hat)
