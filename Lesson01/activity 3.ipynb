# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\steffim\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
url = "https://opendata.socrata.com/api/views/cf4r-dfwe/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)

# %%
df.groupby('State')
df.head
# Out:
#     State          Location Date Posted Date Collected     Sample Type  \
# 0      ID             Boise  03/30/2011     03/23/2011      Air Filter
# 1      ID             Boise  03/30/2011     03/23/2011      Air Filter
# 2      AK            Juneau  03/30/2011     03/23/2011      Air Filter
# 3      AK              Nome  03/30/2011     03/22/2011      Air Filter
# 4      AK              Nome  03/30/2011     03/23/2011      Air Filter
# 5      AK              Nome  03/30/2011     03/23/2011      Air Filter
# 6      AK              Nome  04/04/2011     03/24/2011      Air Filter
# 7      AK              Nome  04/04/2011     03/24/2011      Air Filter
# 8      HI              Oahu  03/30/2011     03/20/2011      Air Filter
# 9      HI              Oahu  03/30/2011     03/20/2011      Air Filter
# 10     HI              Oahu  03/30/2011     03/21/2011      Air Filter
# 11     HI              Oahu  04/04/2011     03/21/2011      Air Filter
# 12     HI              Oahu  03/30/2011     03/23/2011      Air Filter
# 13     CA           Anaheim  03/30/2011     03/20/2011   Air Cartridge
# 14     CA           Anaheim  03/30/2011     03/21/2011   Air Cartridge
# 15     HI              Oahu  03/30/2011     03/23/2011      Air Filter
# 16     CA           Anaheim  04/04/2011     03/25/2011      Air Filter
# 17     CA           Anaheim  03/30/2011     03/22/2011   Air Cartridge
# 18     AK              Nome  03/30/2011     03/22/2011   Air Cartridge
# 19     AK              Nome  03/30/2011     03/23/2011   Air Cartridge
# 20     HI              Oahu  03/30/2011     03/20/2011   Air Cartridge
# 21     HI              Oahu  03/30/2011     03/21/2011   Air Cartridge
# 22     HI              Oahu  03/30/2011     03/23/2011   Air Cartridge
# 23     CA    San Bernardino  03/30/2011     03/23/2011   Air Cartridge
# 24     CA           Anaheim  03/30/2011     03/11/2011      Air Filter
# 25     CA           Anaheim  03/30/2011     03/15/2011      Air Filter
# 26     CA           Anaheim  03/30/2011     03/18/2011      Air Filter
# 27     CA           Anaheim  03/30/2011     03/20/2011      Air Filter
# 28     CA           Anaheim  03/30/2011     03/20/2011      Air Filter
# 29     CA           Anaheim  03/30/2011     03/21/2011      Air Filter
# ..    ...               ...         ...            ...             ...
# 576    CO            Denver  05/24/2011     04/25/2011  Precipitation
# 577    PA        Harrisburg  05/24/2011     04/30/2011  Precipitation
# 578    CT          Hartford  04/26/2011     04/15/2011  Precipitation
# 579    CT          Hartford  04/26/2011     04/18/2011  Precipitation
# 580    HI          Honolulu  05/24/2011     04/04/2011  Precipitation
# 581    KS      Kansas City   04/25/2011     04/15/2011  Precipitation
# 582    TN         Knoxville  04/26/2011     04/19/2011  Precipitation
# 583    TN         Knoxville  05/24/2011     04/26/2011  Precipitation
# 584    TN         Knoxville  05/24/2011     04/29/2011  Precipitation
# 585    MI          Lansing   04/25/2011     04/11/2011  Precipitation
# 586    AR       Little Rock  05/24/2011     04/28/2011  Precipitation
# 587    AL    Montgomery/408  04/26/2011     04/18/2011  Precipitation
# 588    TN        Nashville   04/25/2011     04/14/2011  Precipitation
# 589    TN     Oak Ridge/K25  04/26/2011     04/18/2011  Precipitation
# 590    TN     Oak Ridge/K25  05/24/2011     04/28/2011  Precipitation
# 591    TN    Oak Ridge/K-25  04/25/2011     04/14/2011  Precipitation
# 592    TN  Oak Ridge/Melton  04/25/2011     04/14/2011  Precipitation
# 593    TN  Oak Ridge/Melton  04/26/2011     04/18/2011  Precipitation
# 594    TN  Oak Ridge/Melton  05/24/2011     04/28/2011  Precipitation
# 595    TN    Oak Ridge/Y12E  04/26/2011     04/18/2011  Precipitation
# 596    TN    Oak Ridge/Y12E  05/24/2011     04/28/2011  Precipitation
# 597    TN   Oak Ridge/Y-12E  04/25/2011     04/14/2011  Precipitation
# 598    WA           Olympia  04/25/2011     04/14/2011  Precipitation
# 599    OH       Painesville  05/24/2011     04/29/2011  Precipitation
# 600    OR          Portland  05/24/2011     04/20/2011  Precipitation
# 601    CA          Richmond  04/25/2011     04/14/2011  Precipitation
# 602    CA          Richmond  05/24/2011     04/28/2011  Precipitation
# 603    UT    Salt Lake City  05/24/2011     04/14/2011  Precipitation
# 604    UT    Salt Lake City  05/24/2011     04/28/2011  Precipitation
# 605    NY           Yaphank  05/24/2011     04/28/2011  Precipitation
#
#        Unit      Ba-140       Co-60      Cs-134      Cs-136      Cs-137  \
# 0    pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 1    pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 2    pCi/m3  Non-detect  Non-detect      0.0057         NaN      0.0074
# 3    pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 4    pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 5    pCi/m3  Non-detect  Non-detect       0.016         NaN       0.023
# 6    pCi/m3  Non-detect  Non-detect        0.14  Non-detect        0.12
# 7    pCi/m3  Non-detect  Non-detect         0.1       0.012        0.13
# 8    pCi/m3  Non-detect  Non-detect       0.034         NaN       0.021
# 9    pCi/m3  Non-detect  Non-detect       0.028         NaN       0.036
# 10   pCi/m3  Non-detect  Non-detect       0.076         NaN       0.092
# 11   pCi/m3  Non-detect  Non-detect       0.093  Non-detect        0.12
# 12   pCi/m3  Non-detect  Non-detect          ND         NaN  Non-detect
# 13   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 14   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 15   pCi/m3  Non-detect  Non-detect       0.013         NaN       0.016
# 16   pCi/m3         NaN         NaN       0.026         NaN       0.031
# 17   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 18   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 19   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 20   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 21   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 22   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 23   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 24   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 25   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 26   pCi/m3  Non-detect  Non-detect      0.0012         NaN      0.0017
# 27   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# 28   pCi/m3  Non-detect  Non-detect      0.0076         NaN       0.008
# 29   pCi/m3  Non-detect  Non-detect  Non-detect         NaN  Non-detect
# ..      ...         ...         ...         ...         ...         ...
# 576   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 577   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 578   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 579   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 580   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 581   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 582   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 583   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 584   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 585   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 586   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 587   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 588   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 589   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 590   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 591   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 592   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 593   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 594   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 595   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 596   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 597   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 598   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 599   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 600   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 601   pCi/l  Non-detect  Non-detect         8.9  Non-detect         7.9
# 602   pCi/l  Non-detect  Non-detect         6.6  Non-detect         5.8
# 603   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 604   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 605   pCi/l  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
#
#           I-131       I-132       I-133      Te-129     Te-129m      Te-132
# 0         0.088  Non-detect  Non-detect         NaN         NaN  Non-detect
# 1         0.055  Non-detect  Non-detect         NaN         NaN  Non-detect
# 2         0.067  Non-detect  Non-detect         NaN         NaN      0.0043
# 3         0.096  Non-detect  Non-detect         NaN         NaN  Non-detect
# 4          0.22  Non-detect  Non-detect         NaN         NaN  Non-detect
# 5           0.2       0.019  Non-detect         NaN         NaN       0.027
# 6          0.43       0.094  Non-detect  Non-detect  Non-detect        0.14
# 7          0.39       0.076  Non-detect        0.12       0.061        0.12
# 8           0.2  Non-detect  Non-detect         NaN         NaN  Non-detect
# 9          0.14        0.02  Non-detect         NaN         NaN       0.029
# 10         0.64       0.052  Non-detect         NaN         NaN       0.063
# 11         0.66  Non-detect  Non-detect  Non-detect  Non-detect       0.051
# 12        0.059  Non-detect  Non-detect         NaN         NaN  Non-detect
# 13         0.87  Non-detect  Non-detect         NaN         NaN  Non-detect
# 14          1.9  Non-detect  Non-detect         NaN         NaN  Non-detect
# 15        0.053  Non-detect  Non-detect         NaN         NaN      0.0087
# 16         0.22        0.02         NaN         NaN         NaN       0.023
# 17         0.53  Non-detect  Non-detect         NaN         NaN  Non-detect
# 18         0.34  Non-detect  Non-detect         NaN         NaN  Non-detect
# 19         0.78  Non-detect  Non-detect         NaN         NaN  Non-detect
# 20         0.76  Non-detect  Non-detect         NaN         NaN  Non-detect
# 21          1.4  Non-detect  Non-detect         NaN         NaN  Non-detect
# 22         0.18  Non-detect  Non-detect         NaN         NaN  Non-detect
# 23         0.45  Non-detect  Non-detect         NaN         NaN  Non-detect
# 24   Non-detect  Non-detect  Non-detect         NaN         NaN  Non-detect
# 25   Non-detect  Non-detect  Non-detect         NaN         NaN  Non-detect
# 26        0.046      0.0095  Non-detect         NaN         NaN       0.012
# 27         0.13  Non-detect  Non-detect         NaN         NaN       0.019
# 28         0.13       0.018  Non-detect         NaN         NaN       0.022
# 29         0.17  Non-detect  Non-detect         NaN         NaN       0.031
# ..          ...         ...         ...         ...         ...         ...
# 576  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 577  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 578  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 579         2.5  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 580  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 581         1.5  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 582  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 583  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 584  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 585         3.7  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 586  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 587  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 588  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 589  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 590  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 591  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 592  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 593  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 594  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 595  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 596  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 597  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 598         6.1  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 599  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 600  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 601         5.9  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 602  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 603  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 604  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 605  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
#
# [606 rows x 17 columns]

# %%
df.groupby('State')['Cs-134'].head()
# Out:
# 0      Non-detect
# 1      Non-detect
# 2          0.0057
# 3      Non-detect
# 4      Non-detect
# 5           0.016
# 6            0.14
# 8           0.034
# 9           0.028
# 10          0.076
# 11          0.093
# 12             ND
# 13     Non-detect
# 14     Non-detect
# 16          0.026
# 17     Non-detect
# 23     Non-detect
# 33     Non-detect
# 34          0.012
# 35         0.0084
# 69     Non-detect
# 71     Non-detect
# 72     Non-detect
# 73     Non-detect
# 74     Non-detect
# 84     Non-detect
# 85     Non-detect
# 86     Non-detect
# 102    Non-detect
# 117    Non-detect
#           ...
# 424    Non-detect
# 425    Non-detect
# 430    Non-detect
# 431    Non-detect
# 435    Non-detect
# 438    Non-detect
# 445    Non-detect
# 446    Non-detect
# 447    Non-detect
# 448    Non-detect
# 449    Non-detect
# 455    Non-detect
# 460    Non-detect
# 461    Non-detect
# 462    Non-detect
# 463    Non-detect
# 464    Non-detect
# 467    Non-detect
# 468    Non-detect
# 475    Non-detect
# 481    Non-detect
# 491    Non-detect
# 500    Non-detect
# 542    Non-detect
# 550    Non-detect
# 551           1.4
# 552    Non-detect
# 555    Non-detect
# 574    Non-detect
# 575    Non-detect
# Name: Cs-134, Length: 206, dtype: object

# %%
df.groupby('State')
df[df.apply(lambda x: x.isnumeric())]
df.mean().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-bc408d519e41> in <module>()
#       1 df.groupby('State')
# ----> 2 df[df.apply(lambda x: x.isnumeric())]
#       3 df.mean().head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-71-bc408d519e41> in <lambda>(x)
#       1 df.groupby('State')
# ----> 2 df[df.apply(lambda x: x.isnumeric())]
#       3 df.mean().head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: ("'Series' object has no attribute 'isnumeric'", 'occurred at index State')

# %%
df.groupby(['State', 'Location']).agg({'Cs-134':['mean', 'std'], 'Te-129':['min', 'max']})
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-66-f6deaf44d055> in <module>()
# ----> 1 df.groupby(['State', 'Location']).agg({'Cs-134':['mean', 'std'], 'Te-129':['min', 'max']})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     496
#     497                 try:
# --> 498                     result = _agg(arg, _agg_1dim)
#     499                 except SpecificationError:
#     500
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#     431                                              "in aggregation")
# --> 432                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     433
#     434             def _agg_2dim(name, how):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     764             # but not the class list / tuple itself.
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#     768             cyfunc = self._is_cython_func(func_or_funcs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     838                 obj._reset_cache()
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#     842         if any(isinstance(x, DataFrame) for x in compat.itervalues(results)):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     758         _level = kwargs.pop('_level', None)
#     759         if isinstance(func_or_funcs, compat.string_types):
# --> 760             return getattr(self, func_or_funcs)(*args, **kwargs)
#     761
#     762         if isinstance(func_or_funcs, compat.Iterable):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     836
#     837         if len(output) == 0:
# --> 838             raise DataError('No numeric types to aggregate')
#     839
#     840         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
df('State').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2d6bacfa25d1> in <module>()
# ----> 1 df('State').mean()
#
# TypeError: 'DataFrame' object is not callable

# %%
df_num = df.groupby(['State']).mean()
df_num.head()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-43-ff89d1c63521> in <module>()
# ----> 1 df_num = df.groupby(['State']).mean()
#       2 df_num.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     141
#     142         if len(new_blocks) == 0:
# --> 143             raise DataError('No numeric types to aggregate')
#     144
#     145         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate
